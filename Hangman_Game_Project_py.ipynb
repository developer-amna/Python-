# %% [markdown]
# <a href="https://colab.research.google.com/github/developer-amna/Python-/blob/main/Hangman_Game_Project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
    words = ["python", "computer", "programming", "hangman", "developer"]
    word = random.choice(words)
    guessed = ["_"] * len(word)
    attempts = 6
    used_letters = []

    print("Welcome to Hangman Game!")
    print("Word:", " ".join(guessed))

    while attempts > 0 and "_" in guessed:
        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter only one alphabet letter.")
            continue

        if guess in used_letters:
            print("You already guessed that letter:", guess)
            continue

        used_letters.append(guess)

        if guess in word:
            for i in range(len(word)):
                if word[i] == guess:
                    guessed[i] = guess
            print("Correct! Word:", " ".join(guessed))
        else:
            attempts -= 1
            print("Wrong guess! Attempts left:", attempts)

        print("Used letters:", ", ".join(used_letters))

    if "_" not in guessed:
        print("🎉 Congratulations! You guessed the word:", word)
    else:
        print("😢 Game Over! The word was:", word)

# Run the game
hangman()
# Out:
# Welcome to Hangman Game!
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter: d
# Correct! Word: d _ _ _ _ _ _ _ _
# Used letters: d
# Guess a letter: e
# Correct! Word: d e _ e _ _ _ e _
# Used letters: d, e
# Guess a letter: v
# Correct! Word: d e v e _ _ _ e _
# Used letters: d, e, v
# Guess a letter: l
# Correct! Word: d e v e l _ _ e _
# Used letters: d, e, v, l
# Guess a letter: o
# Correct! Word: d e v e l o _ e _
# Used letters: d, e, v, l, o
# Guess a letter: p
# Correct! Word: d e v e l o p e _
# Used letters: d, e, v, l, o, p
# Guess a letter: r
# Correct! Word: d e v e l o p e r
# Used letters: d, e, v, l, o, p, r
# 🎉 Congratulations! You guessed the word: developer
